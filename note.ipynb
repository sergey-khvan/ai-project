# %%
import os
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, random_split
from torchvision import transforms
from tqdm import tqdm

from model import VGG

# %%
from dataset import GrapeDataset

# %%
def create_annotations(dir_path):
    """ 
    Returns a Dataframe with images and labels
    """
    X = []
    y = []
    i = 0
    for path in tqdm(sorted(os.listdir(dir_path))):
        if not path.startswith('.'):
            for file in sorted(os.listdir(dir_path + path)):
                if not file.startswith('.'):
                    X.append(path+'/'+file)
                    y.append(i)
            i +=1
    print(f'{len(X)} images loaded from {dir_path} directory.')
    return pd.DataFrame({'filename':X,
                        'label':y})

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
test_path = 'data/test/'
train_path = 'data/train/'    
# Hyperparameters
batch_size = 4
learning_rate = 1e-3
num_epochs = 10
# Loading data
ann_train = create_annotations(train_path)
ann_test = create_annotations(test_path)

transform = transforms.Compose([ transforms.ToTensor(), transforms.Resize((224,224))])
train_data = GrapeDataset(img_dir=train_path, ann_df=ann_train,transform=transform)
test_data = GrapeDataset(img_dir=test_path, ann_df=ann_test,transform=transform)

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True)

# Loading the model
model = VGG(num_classes=4)
model.to(device)
# Loss and Optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 114.57it/s]
# 7222 images loaded from data/train/ directory.
# 100%|██████████| 5/5 [00:00<00:00, 401.84it/s]
# 1805 images loaded from data/test/ directory.

# %%
X, y = next(iter(train_loader))

# %%
device = "mps"
model.to(device)
# Out:
# VGG(
#   (conv_stack): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU()
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU()
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU()
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU()
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU()
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU()
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU()
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU()
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU()
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc_stack): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=4, bias=True)
#   )
# )

# %%
num_epochs = 1000
for epoch in range(num_epochs):
    X, y = X.to(device), y.to(device)
    preds = model(X)
    loss = loss_fn(preds, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print(loss)
# Out:
# tensor(1.4733, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.2386, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(1.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.9614, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.8681, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.7757, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.7149, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6477, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6539, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.6078, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4467, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4094, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3855, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.4317, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3499, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2183, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3192, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3408, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.3213, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2422, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2455, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.2035, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1420, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1381, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1205, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1148, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1436, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1605, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1338, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1224, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1419, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.1177, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0571, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0758, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0910, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0686, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0657, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0841, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0792, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0590, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0477, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0650, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0450, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0536, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0820, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0508, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0509, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0445, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0401, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0410, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0450, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0460, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0314, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0356, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0352, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0295, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0238, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0196, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0324, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0278, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0310, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0202, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0373, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0270, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0360, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0207, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0246, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0266, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0254, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0153, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0287, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0209, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0375, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0307, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0264, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0233, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0187, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0188, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0195, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0133, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0098, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0217, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0253, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0192, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0146, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0121, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0272, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0135, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0158, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0163, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0205, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0196, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0180, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0144, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0170, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0118, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0106, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0139, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0256, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0187, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0160, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0094, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0127, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0131, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0130, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0122, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0142, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0105, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0130, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0135, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0192, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0090, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0237, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0194, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0094, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0073, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0074, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0096, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0208, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0148, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0232, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0103, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0114, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0092, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0099, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0116, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0108, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0083, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0072, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0091, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0126, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0070, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0186, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0135, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0086, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0101, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0081, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0128, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0097, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0076, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0101, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0110, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0091, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0138, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0083, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0070, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0084, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0082, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0085, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0118, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0110, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0076, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0063, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0046, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0070, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0087, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0079, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0095, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0088, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0070, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0060, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0110, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0075, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0061, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0093, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0064, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0087, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0097, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0052, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0046, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0063, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0073, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0104, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0081, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0076, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0092, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0095, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0089, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0109, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0121, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0065, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0061, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0088, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0111, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0088, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0115, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0104, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0059, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0063, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0069, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0087, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0093, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0062, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0063, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0062, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0103, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0072, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0075, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0063, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0058, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0055, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0063, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0058, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0079, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0043, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0090, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0070, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0048, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0122, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0077, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0059, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0044, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0046, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0045, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0041, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0042, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0057, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0062, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0055, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0054, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0075, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0039, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0065, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0055, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0046, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0041, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0037, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0062, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0041, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0065, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0047, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0045, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0083, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0043, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0056, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0049, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0038, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0037, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0047, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0058, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0050, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0061, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0054, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0097, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0044, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0048, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0045, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0050, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0068, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0049, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0035, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0058, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0075, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0035, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0037, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0052, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0037, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0046, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0046, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0036, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0073, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0042, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0043, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0043, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0088, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0042, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0043, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0043, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0060, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0047, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0054, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0058, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0037, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0043, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0055, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0038, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0064, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0041, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0042, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0054, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0060, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0043, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0039, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0048, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0041, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0048, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0038, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0038, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0043, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0061, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0051, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0039, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0050, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0049, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0056, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0041, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0036, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0036, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0050, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0037, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0035, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0044, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0050, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0045, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0047, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0067, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0051, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0045, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0035, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0048, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0055, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0035, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0036, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0039, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0039, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0044, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0044, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0035, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0055, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0036, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0049, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0049, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0035, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0035, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0056, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0036, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0039, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0047, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0041, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0041, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0041, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0040, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0047, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0048, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0038, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0038, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0036, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0037, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0035, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0048, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0038, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0031, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0034, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0039, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0028, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0042, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0005, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0005, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0032, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0005, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0022, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0006, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0011, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0008, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(0.0007, device='mps:0', grad_fn=<NllLossBackward0>)

# %%
preds
# Out:
# tensor([[-2.3598,  6.5041, -1.5183, -2.7046],
#         [-1.2176, -1.3093,  6.5731, -2.0980],
#         [-1.3654,  6.7710, -0.9830, -2.8361],
#         [ 6.5101, -2.6940, -2.0533, -2.6860]], device='mps:0',
#        grad_fn=<LinearBackward0>)

# %%
y
# Out:
# tensor([1, 2, 1, 0], device='mps:0')

# %%
for epoch in range(num_epochs):
    train_running_loss = 0.0
    loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=False)
    # Train
    model.train()
    for idx, (X,y) in loop:
        X, y = X.to(device), y.to(device)

        preds = model(X)
        loss = loss_fn(preds, y)
        train_running_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # update progress bar
        loop.set_description(f"Epoch:[{epoch}/{num_epochs}](Train)")
        loop.set_postfix(train_loss=loss.item())

    train_loss = train_running_loss / (idx + 1)

    # Val
    val_running_loss = 0.0
    run_accuracy = 0
    model.eval()
    loop = tqdm(enumerate(test_loader), total=len(test_loader), leave=False)
    with torch.no_grad():
        for idx, (X,y) in loop:
            X, y = X.to(device), y.to(device)

            preds = model(X)
            loss = loss_fn(preds, y)
            val_running_loss += loss.item()
            # accuracy = calc_accuracy(preds, mask, cfg.THR)
            # run_accuracy += accuracy.item()
            loop.set_description(f"Epoch:[{epoch}/{num_epochs}](Val)")
            # loop.set_postfix(val_loss=loss.item(), acc=accuracy.item())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 9
#       6 for idx, (X,y) in loop:
#       7     X, y = X.to(device), y.to(device)
# ----> 9     preds = model(X)
#      10     loss = loss_fn(preds, y)
#      11     train_running_loss += loss.item()
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/projects/unipd/ai_unipd/model.py:26, in VGG.forward(self, x)
#      25 def forward(self, x):
# ---> 26     x = self.conv_stack(x)
#      27     x = torch.flatten(x,1)
#      28     x = self.fc_stack(x)
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File /usr/local/lib/python3.12/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
